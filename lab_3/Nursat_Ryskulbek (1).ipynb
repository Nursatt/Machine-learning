# %%
import numpy as np 
import seaborn 
import pandas as pd
import os
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import math 
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Second by Sklearn

# %% [markdown]
# First by formula

# %%
data=pd.read_csv('Fuel_Consumption_2000-2022.csv')

# %% [markdown]
# ### FIRST METHOD

# %%
data
# Out:
#       YEAR    MAKE    MODEL            VEHICLE CLASS  ENGINE_SIZE  CYLINDERS  \
# 0     2000   ACURA    1.6EL                  COMPACT          1.6          4
# 1     2000   ACURA    1.6EL                  COMPACT          1.6          4
# 2     2000   ACURA    3.2TL                 MID-SIZE          3.2          6
# 3     2000   ACURA    3.5RL                 MID-SIZE          3.5          6
# 4     2000   ACURA  INTEGRA               SUBCOMPACT          1.8          4
# ...    ...     ...      ...                      ...          ...        ...
# 1244  2001  TOYOTA   SIENNA                  MINIVAN          3.0          6
# 1245  2001  TOYOTA   TACOMA  PICKUP TRUCK - STANDARD          2.4          4
# 1246  2001  TOYOTA   TACOMA  PICKUP TRUCK - STANDARD          2.4          4
# 1247  2001  TOYOTA   TACOMA  PICKUP TRUCK - STANDARD          2.7          4
# 1248  2001  TOYOTA   TACOMA  PICKUP TRUCK - STANDARD          3.4          6
#
# ...

# %%
data.describe()
# Out:
#               YEAR  ENGINE_SIZE    CYLINDERS  FUEL_CONSUMPTION  \
# count  1249.000000  1249.000000  1249.000000       1249.000000
# mean   2000.488391     3.304964     5.850280         13.166453
# std       0.500065     1.223524     1.587966          2.986477
# min    2000.000000     1.000000     3.000000          3.900000
# 25%    2000.000000     2.300000     4.000000         11.100000
# 50%    2000.000000     3.000000     6.000000         12.900000
# 75%    2001.000000     4.300000     6.000000         15.100000
# max    2001.000000     8.000000    12.000000         27.700000
#
#        HWY (L/100 km)  COMB (L/100 km)   COMB (mpg)    EMISSIONS
# count     1249.000000      1249.000000  1249.000000  1249.000000
# mean         9.085348        11.329544    26.285028   259.923939
# std          2.114492         2.554436     6.508779    57.916785
# min          3.200000         3.600000    12.000000    83.000000
# 25%          7.500000         9.600000    21.000000   221.000000
# ...

# %%
plt.figure(figsize=(6,4))
plt.scatter(data.ENGINE_SIZE,data.FUEL_CONSUMPTION, alpha=0.2)
plt.xlabel('Engine size')
plt.ylabel('Fuel cunsumption')
# Out:
# Text(0, 0.5, 'Fuel\xa0cunsumption')

# %%
model=LinearRegression()

# %%
X=pd.DataFrame(data.ENGINE_SIZE)
y=pd.DataFrame(data.FUEL_CONSUMPTION)

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
plt.figure(figsize=(6,4))
plt.scatter(data.ENGINE_SIZE,data.FUEL_CONSUMPTION, alpha=0.2)
plt.xlabel('Engine size')
plt.ylabel('Fuel cunsumption')
# Out:
# Text(0, 0.5, 'Fuel\xa0cunsumption')

# %%
x=pd.DataFrame(data.ENGINE_SIZE)
y=pd.DataFrame(data.FUEL_CONSUMPTION)

# %%
plt.scatter(data.ENGINE_SIZE,data.FUEL_CONSUMPTION, alpha = 0.4)
plt.plot(x ,model.predict(x),color='red', linewidth = 2)
plt.xlabel('engine')
plt.ylabel('fuel_consumotion')
# Out:
# Text(0, 0.5, 'fuel_consumotion')

# %% [markdown]
# ### Finding Least squares line

# %%
n=1248
xsum=sum(data.ENGINE_SIZE)
ysum=sum(data.FUEL_CONSUMPTION)
xy=sum(data.ENGINE_SIZE*data.FUEL_CONSUMPTION)
xsqsum=sum(data.ENGINE_SIZE**2)
ysqsum=sum(data.FUEL_CONSUMPTION)
m=(n*xy-xsum*ysum)/(n*xsqsum-xsum**2)
b=(ysum-m*(xsum))/n
x=data.ENGINE_SIZE
y=data.ENGINE_SIZE*m+b
print(m,b)
# Out:
# 2.084660480585391 6.281754809448312

# %% [markdown]
# ### Correlation coeff

# %%
Corr=(n*xy-xsum*ysum)/(math.sqrt(n*xsqsum-xsum**2)*(n*ysqsum-ysum**2)**0.5)
print('{:.10f}'.format(Corr))
# Out:
# 0.0000000000-0.2007682068j

# %% [markdown]
# ### Second Method

# %%
data
# Out:
#       YEAR    MAKE    MODEL            VEHICLE CLASS  ENGINE_SIZE  CYLINDERS  \
# 0     2000   ACURA    1.6EL                  COMPACT          1.6          4
# 1     2000   ACURA    1.6EL                  COMPACT          1.6          4
# 2     2000   ACURA    3.2TL                 MID-SIZE          3.2          6
# 3     2000   ACURA    3.5RL                 MID-SIZE          3.5          6
# 4     2000   ACURA  INTEGRA               SUBCOMPACT          1.8          4
# ...    ...     ...      ...                      ...          ...        ...
# 1244  2001  TOYOTA   SIENNA                  MINIVAN          3.0          6
# 1245  2001  TOYOTA   TACOMA  PICKUP TRUCK - STANDARD          2.4          4
# 1246  2001  TOYOTA   TACOMA  PICKUP TRUCK - STANDARD          2.4          4
# 1247  2001  TOYOTA   TACOMA  PICKUP TRUCK - STANDARD          2.7          4
# 1248  2001  TOYOTA   TACOMA  PICKUP TRUCK - STANDARD          3.4          6
#
# ...

# %%
model=LinearRegression()

# %%
X=pd.DataFrame(data.ENGINE_SIZE)
Y=pd.DataFrame(data.FUEL_CONSUMPTION)

# %%
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([[2.09577289]])

# %%
model.intercept_
# Out:
# array([6.23999927])

# %%
plt.scatter(data.ENGINE_SIZE,data.FUEL_CONSUMPTION)
plt.xlabel('ENGINE_SIZE')
plt.ylabel('FUEL_CONSUMPTION')
plt.plot(X['ENGINE_SIZE'],model.predict(X),color='red')

# %%
model.score(X,Y)
# Out:
# 0.7372165952521164
